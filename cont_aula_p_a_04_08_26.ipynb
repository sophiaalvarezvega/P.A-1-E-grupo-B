# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiaalvarezvega/P.A-1-E-grupo-B/blob/main/cont_aula_p_a_04_08_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "maria"
idade = 16
altura = 1.69
nota = 10
cidade = "Ribeirão Pires"

print(nome)
print(idade)
print(altura)
print(nota)
print(cidade)

print(type(nome))
print(type(idade))
print(type(altura))
print(type(nota))
print(type(cidade))
# Out:
# maria
# 16
# 1.69
# 10
# Ribeirão Pires
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
nota1 = 7.5
nota2 = 8
nota3 = 6.5

media = (7.5 + 8 + 6.5) / 3
print(media)
# Out:
# 7.333333333333333

# %%
#texto1 = "20"
#texto2 = "3.5"
#numero = 8

texto1 = int(20) + 10
texto2 = float(3.5) * 2
numero = str("8 anos")

print(texto1)
print(texto2)
print(numero)
# Out:
# 30
# 7.0
# 8 anos

# %%
dobrode15 = 15 * 2
metadede90 = 90 / 2
restodadivisaode17por5 = 17 % 5
doiselevadoaquatro = 2**4
mediadedezeoitoeseis = (10 + 8 + 6) / 3

print(dobrode15)
print(metadede90)
print(restodadivisaode17por5)
print(doiselevadoaquatro)
print(mediadedezeoitoeseis)
# Out:
# 30
# 45.0
# 2
# 16
# 8.0

# %%
idade = 16
nota = 8.5
preco = 45.0

idade >= 18
nota > 7
preco <= 50
idade == 16
nota != 10
# Out:
# True

# %%
produto = int(80)
desconto = produto / 10
valor = produto - desconto

print(f"O valor do produto é {produto}")
print(f"O valor do desconto é {desconto}")
print(f"O valor final é {valor}")
print(valor < 75)
# Out:
# O valor do produto é 80
# O valor do desconto é 8.0
# O valor final é 72.0
# True

# %%
nome = input("Digite o nome do aluno")
nota1 = float(input("Digite a primeira nota"))
nota2 = float(input("Digite a segunda nota"))
media = (nota1 + nota2) / 2

print(f"O aluno {nome} tirou média {media}")
# Out:
# Digite o nome do alunoJoão
# Digite a primeira nota7
# Digite a segunda nota7
# O aluno João tirou média 7.0

# %%
idade = int(input("Digite a sua idade"))

if idade >= 18:
  print(str("Você pode dirigir"))
else:
  print(str("Você não pode dirigir"))
# Out:
# Digite a sua idade8
# Você não pode dirigir

# %%
numero = float(input("Digite um número"))

if numero % 2 == 0:
   print("O número é par")
else:
    print("O número é ímpar")
# Out:
# Digite um número24
# O número é par

# %%
a = float(input("Digite um número"))
b = float(input("Digite um outro número"))

if a > b:
  print(f"{a} é maior que {b}")
elif a == b:
  print("Os números digitados são iguais.")
else:
  print(f"{b} é maior que {a}")
# Out:
# Digite um número9
# Digite um outro número2
# 9.0 é maior que 2.0

# %%
nota = int(input("Digite a nota do aluno"))

if nota >= 7:
   print("Aprovado")
elif nota >= 5 and nota < 7:
   print("Ficou de recuperação")
else:
  print("Reprovado")
# Out:
# Digite a nota do aluno3
# Reprovado

# %%
valor = int(input("Digite o valor da compra"))
desconto = valor / 10
valorfinal = valor - desconto

if valor >= 100:
  print(f"O valor final é {valorfinal}")
else:
  print(f"O valor normal é {valor}")
# Out:
# Digite o valor da compra67
# O valor normal é 67

# %%
n = int(input("Digite um número"))

if n > 0:
  print("O número é positivo")
elif n == 0:
  print("O número é zero")
else:
  print("O número é negativo")
# Out:
# Digite um número-1
# O número é negativo

# %%
idade = int(input("Digite sua idade"))

if idade < 12:
  print("Criança")
elif idade == 12 or idade <= 17:
  print("Adolescente")
elif idade == 18 or idade <= 59:
  print("Adulto")
else:
  print("Idoso")
# Out:
# Digite sua idade45
# Adulto

# %%
nota1 = int(input("Digite a primeira nota"))
nota2 = int(input("Digite a segunda nota"))
media = (nota1 + nota2) / 2

if media >= 7:
  print("Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a primeira nota4
# Digite a segunda nota6
# Reprovado

# %%
usuario = input("Digite o nome de usuário")
senha = int(input("Digite a senha"))

if usuario == "admin" and senha == 1234:
  print("Login realizado com sucesso")

else:
  print("Usuário ou senha incorretos")
# Out:
# Digite o nome de usuárioadmin
# Digite a senha1234
# Login realizado com sucesso

# %%
peso = float(input("Digite seu peso"))
altura = float(input("Digite a sua altura"))

imc = peso / (altura * altura)

if imc < 18.5:
  print("Abaixo do peso")
elif imc > 18.5 and imc < 24.9:
  print("Peso normal")
elif imc >= 25 and imc < 29.9:
  print("Sobrepeso")
else:
  print("Obesidade")
# Out:
# Digite seu peso34
# Digite a sua altura1.60
# Abaixo do peso
