# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiaalvarezvega/P.A-1-E-grupo-B/blob/main/22_09_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = {"nome": "Lucas", "idade": 17, "curso": "Informática"}
print(aluno)
# Out:
# {'nome': 'Lucas', 'idade': 17, 'curso': 'Informática'}

# %%
aluno2 = {"nome": "Ana", "idade": 15, "curso": "Administração"}
print(aluno2["nome"])
print(aluno2["idade"])
print(aluno2["curso"])
# Out:
# Ana
# 15
# Administração

# %%
produto = {"nome": "Teclado", "preço": 150.00, "estoque": 10}
produto["preço"] = 120.00
print(produto)
# Out:
# {'nome': 'Teclado', 'preço': 120.0, 'estoque': 10}

# %%
aluno3 = {"nome": "Paulo", "idade": 18}
aluno3["curso"] = "Engenharia"
print(aluno3)
# Out:
# {'nome': 'Paulo', 'idade': 18, 'curso': 'Engenharia'}

# %%
filme = {
    "título": "Star Wars",
    "ano": 1977,
    "gênero": "Ficção Científica",
    "nota": 8.8,
}
print(filme["título"])
print(filme["ano"])
print(filme["gênero"])
print(filme["nota"])
# Out:
# Star Wars
# 1977
# Ficção Científica
# 8.8

# %%
numeros = {1, 2, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
numeros = {1, 2, 2, 3, 3, 3, 4, 5}
print(numeros )
# Out:
# {1, 2, 3, 4, 5}

# %%
frutas = {"maçã", "banana", "laranja"}
frutas.add("morango")
print(frutas)
# Out:
# {'morango', 'laranja', 'maçã', 'banana'}

# %%
cores = {"vermelho", "azul", "verde", "amarelo"}
cores.remove("verde")
print(cores)
# Out:
# {'vermelho', 'azul', 'amarelo'}

# %%
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]
nomes_unicos = set(nomes)
print(nomes_unicos)
# Out:
# {'Theo', 'Maitê', 'Gael', 'Luna', 'Yris', 'Ravi'}
