# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiaalvarezvega/P.A-1-E-grupo-B/blob/main/Exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas = ["maçã", "banana", "laranja", "morango"]
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0], nomes[1], nomes[3])
# Out:
# Rebeca Guilherme Kyara

# %%
cores = ["vermelho", "azul", "verde"]
cores[1] = "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
numeros = (10, 20, 30, 40, 50)
print(numeros[0], numeros[2], numeros[4])
# Out:
# 10 30 50

# %%
aluno = ("Thiago", 16, "Informática")
print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Thiago
# 16
# Informática

# %%
cores = ("vermelho", "azul", "verde")
cores[1] = "amarelo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1660/2472117528.py in <cell line: 0>()
#       1 cores = ("vermelho", "azul", "verde")
# ----> 2 cores[1] = "amarelo"
#
# TypeError: 'tuple' object does not support item assignment

# %%
numeros_tupla = (2, 4, 2, 6, 2, 8, 10)
print(numeros_tupla.count(2))
# Out:
# 3
