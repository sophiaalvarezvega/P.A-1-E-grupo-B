# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiaalvarezvega/P.A-1-E-grupo-B/blob/main/C%C3%B3pia_de_C%C3%B3pia_de_Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TC = int(30)

TF = (TC * 9/5) + 32

print(f"{TF}")
# Out:
# 86.0

# %%
numero = int(2)

triplo_do_numero = (3 * numero)

print(f"{triplo_do_numero}")
# Out:
# 6
