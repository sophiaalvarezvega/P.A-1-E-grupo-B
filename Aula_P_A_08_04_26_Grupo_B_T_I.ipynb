# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiaalvarezvega/P.A-1-E-grupo-B/blob/main/Aula_P_A_08_04_26_Grupo_B_T_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Escrever um programa que calcula a média do bimestre do aluno e se ele foi aprovado ou reprovado

nome = str(input("Digite seu nome: "))

nota1 = float(input("Digite sua primeira nota"))
nota2 = float(input("Digite sua segunda nota"))
nota3 = float(input("Digite sua terceira nota"))
nota4 = float(input("Digite sua quarta nota"))

media = (nota1 + nota2 + nota3 + nota4) / 4

if media > 10:
    print("Digite uma nota válida, menor que 10")
else:
    if media >= 7:
        print("Você foi aprovado! :)")
    else:
        print("Você foi reprovado :(")

# %%
#Escrever um programa que refere se os valores de 3 lados, verifica se é um triãngulo válido e o tipo de triãngulo:

#Um triângulo tem 3 lados, então é necessário colocar 3 inputs para o usuário digitar os valores de cada lado.
#Assim, oa valores dos 3 lados:

lado1 = int(input("Digite o lado1"))
lado2 = int(input("Digite o lado2"))
lado3 = int(input("Digite o lado3"))

if lado1
#O tipo em que esse triângulo se classifica:

if lado1 == lado2 == lado3:
    print("Esse triãngulo é equilátero")
elif lado1 == lado2 or lado2 == lado3 or lado3 == lado1 or lado1 == lado3 or lado2 == lado1:
    print("Esse triãngulo é isósceles")
else:
    print("Esse triãngulo é escaleno")

# %%
#Fazer um programa que identifica se o número é par ou ímpar:

numero = int(input("Digite um número: "))

if numero % 2 == 0:
    print("Esse número é par")
else:
    print("ESse número é ímpar")
# Out:
# Digite um número: 890097
# ESse número é ímpar
